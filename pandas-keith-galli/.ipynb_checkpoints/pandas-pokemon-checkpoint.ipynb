# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')

# Reading it as excel
# df_xlsx = pd.read_excel('pokemon_data.xlsx')
# print(df_xlsx)

# Show top or bottom
# print(df.tail(3))
# print(df.head(3))

# %%
## Read Headers
print(df.columns)

## Read each columns
# print(df['Name'][0:5])
# print(df.Name[0:5]) # Same as above
# print(df[['Name','Type 1']][0:5]) # Specific headers

## Read Each Row
# print(df.iloc[0:4])# interger location

## Read a specific location (R,C)
# print()
# print(df.iloc[2,2])

# Prints through each row in an unformatted manner
for index, row in df.iterrows():
#     print(index, row)
#     print(index, row['Name']) # Just the name
    df.loc[df['Type 1'] == "Fire"]
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# Get the basic statistics about the dataset
# df.describe()

# Reverse sorting
# df.sort_values('Name', ascending=False)
df.sort_values(['Type 1', 'HP'], ascending=[1,0]) # Sorting data
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# df['Total'] = df['HP'] # + df['Attack'] + df['Defense']
# df['Total'].sort_values('Total') # How do i sort it based on this new column?

# df.drop(columns=['Total'])

# Axis indicates direction
# df['Total'] = df.iloc[:, 4:10].sum(axis=1) # All the columns?

# cols = list(df.columns)
# df = df[cols[0:4] + [cols[-1]]+cols[4:12]]

# df.head(5)

# %%
# df.to_csv('modified.csv')

# df.to_excel('modfied.xlsx', index=False)

df.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# ## Filtering Data

# %%
# |, and, & are all possible ways to join the conditions 
# new_df = df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
# new_df = new_df.reset_index(drop=True)
# df.loc[~df['Name'].str.contains('Mega')]

# re stands for regular expression
import re
df.loc[df['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %% [markdown]
# ## Conditional Changes

# %%
# Used the condition of type 1 is fire and changed the legendary status to true
# df.loc[df['Type 1'] == 'Fire', 'Legendary'] = True

# %%
# Groupby
# This is moreso data science, similar to what we do in SQL
# Count, mean, sum are available, maybe more if looking at the documnetation
df.groupby(['Type 1']).mean().sort_values('Attack', ascending=False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# ...

# %% [markdown]
# ## Working with large amounts of data

# %%
# Breaking it down into chunks of 200 rows when there is large data

for df in pd.read_csv('modified.csv', chunksize=200):
    print(df)
# Out:
#      Unnamed: 0    #                   Name    Type 1  Type 2   HP  Attack  \
# 0             0    1              Bulbasaur     Grass  Poison   45      49
# 1             1    2                Ivysaur     Grass  Poison   60      62
# 2             2    3               Venusaur     Grass  Poison   80      82
# 3             3    3  VenusaurMega Venusaur     Grass  Poison   80     100
# 4             4    4             Charmander      Fire     NaN   39      52
# ..          ...  ...                    ...       ...     ...  ...     ...
# 195         195  181               Ampharos  Electric     NaN   90      75
# 196         196  181  AmpharosMega Ampharos  Electric  Dragon   90      95
# 197         197  182              Bellossom     Grass     NaN   75      80
# 198         198  183                 Marill     Water   Fairy   70      20
# 199         199  184              Azumarill     Water   Fairy  100      50
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...
